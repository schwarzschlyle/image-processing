# %% [markdown]
# # Altering the Input-Output Curve

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt


def alter_io(point1, point2, point3):

    # Load an image
    img = cv2.imread('dark_galaxy.jpg')

    # Define the input and output curves
    input_curve = np.array([0, 50, 150, 255])
    output_curve = np.array([0, point1, point2, point3])


    # Create the lookup table using linear interpolation
    lut = np.interp(np.arange(256), input_curve, output_curve).astype(np.uint8)
    
    
    # Plot the input and output curves
    fig, ax = plt.subplots()
    ax.plot(input_curve, output_curve, label='Input-Output Curve')

    # Plot the LUT curve
    ax.plot(np.arange(256), lut, label='LUT Curve')
    plt.savefig(f'lut_point1_{point1}.jpg')

    # Apply the lookup table to the image
    img_processed = cv2.LUT(img, lut)

    # Save the output image
    # cv2.imwrite(f'io_point1_{point1}.jpg', img_processed)
    # cv2.imwrite(f'io_point2_{point3}.jpg', img_processed)
    # cv2.imwrite(f'io_point3_{point3}.jpg', img_processed)


for i in range(0,10,1):
    alter_io(i*50, 150, 255)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt


def alter_io(point1, point2, point3):

    # Load an image
    img = cv2.imread('dark_galaxy.jpg')

    # Define the input and output curves
    input_curve = np.array([0, 50, 150, 255])
    output_curve = np.array([0, point1, point2, point3])


    # Create the lookup table using linear interpolation
    lut = np.interp(np.arange(256), input_curve, output_curve).astype(np.uint8)

    # Plot the input and output curves
    fig, ax = plt.subplots()
    ax.plot(input_curve, output_curve, label='Input-Output Curve')

    # Plot the LUT curve
    ax.plot(np.arange(256), lut, label='LUT Curve')
    plt.savefig(f'lut_point2_{point2}.jpg')

    # Apply the lookup table to the image
    img_processed = cv2.LUT(img, lut)

    # Save the output image
    # cv2.imwrite(f'io_point1_{point1}.jpg', img_processed)
    # cv2.imwrite(f'io_point2_{point2}.jpg', img_processed)
    # cv2.imwrite(f'io_point3_{point3}.jpg', img_processed)


for i in range(0,10,1):
    alter_io(50, i*50, 255)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt


def alter_io(point1, point2, point3):

    # Load an image
    img = cv2.imread('dark_galaxy.jpg')

    # Define the input and output curves
    input_curve = np.array([0, 50, 150, 255])
    output_curve = np.array([0, point1, point2, point3])


    # Create the lookup table using linear interpolation
    lut = np.interp(np.arange(256), input_curve, output_curve).astype(np.uint8)

    # Plot the input and output curves
    fig, ax = plt.subplots()
    ax.plot(input_curve, output_curve, label='Input-Output Curve')

    # Plot the LUT curve
    ax.plot(np.arange(256), lut, label='LUT Curve')
    plt.savefig(f'lut_point3_{point3}.jpg')

    # Apply the lookup table to the image
    img_processed = cv2.LUT(img, lut)

    # Save the output image
    # cv2.imwrite(f'io_point1_{point1}.jpg', img_processed)
    # cv2.imwrite(f'io_point2_{point3}.jpg', img_processed)
    # cv2.imwrite(f'io_point3_{point3}.jpg', img_processed)


for i in range(0,10,1):
    alter_io(50, 150, i*50)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load an image
img = cv2.imread('dark_galaxy.jpg')

# Define the input and output curves
input_curve = np.array([0, 40, 150, 200, 255])
output_curve = np.array([0, 30, 200, 245, 255])

# Create the lookup table using linear interpolation
lut = np.interp(np.arange(256), input_curve, output_curve).astype(np.uint8)

# Apply the lookup table to the image
img_processed = cv2.LUT(img, lut)

# Plot the input and output curves
fig, ax = plt.subplots()
ax.plot(input_curve, output_curve, label='Input-Output Curve')

# Plot the LUT curve
ax.plot(np.arange(256), lut, label='LUT Curve')
plt.savefig(f'crip_lut_io.jpg')

# Display the original and processed images
fig, ax = plt.subplots(ncols=2, figsize=(10, 5))
ax[0].imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
ax[0].set_title('Original Image')
ax[1].imshow(cv2.cvtColor(img_processed, cv2.COLOR_BGR2RGB))
ax[1].set_title('Processed Image')

plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load an image
img = cv2.imread('dark_galaxy.jpg')

# Define the input and output curves
input_curve = np.array([0, 40, 150, 200, 255])
output_curve = np.array([0, 30, 200, 245, 255])

# Create the lookup table using linear interpolation
lut = np.interp(np.arange(256), input_curve, output_curve).astype(np.uint8)

# Apply the lookup table to the image
img_processed = cv2.LUT(img, lut)

# Plot the input and output curves
fig, ax = plt.subplots()
ax.plot(input_curve, output_curve, label='Input-Output Curve')

# Plot the LUT curve
ax.plot(np.arange(256), lut, label='LUT Curve')

# Display the original and processed images
fig, ax = plt.subplots(ncols=2, figsize=(10, 5))
ax[0].imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
ax[0].set_title('Original Image')
ax[1].imshow(cv2.cvtColor(img_processed, cv2.COLOR_BGR2RGB))
ax[1].set_title('Processed Image')

plt.show()

# Save the original and processed images
cv2.imwrite('original_image.jpg', img)
cv2.imwrite('processed_image.jpg', img_processed)
# Out:
# True

# %% [markdown]
# ## Rendering

# %% [markdown]
# ### Point1 Render

# %%
import imageio
import os


# using a raw string
# directory = r"C:\Users\Lyle\Desktop\Computation and Modelling\image-processing\sine_plots\varying_freq"
directory = r"C:\Users\Lyle\Desktop\Computation and Modelling\image-processing\alter_io\point1"


# create a list of image file names in the directory
image_files = os.listdir(directory)

# sort the list of image file names to ensure proper ordering in the GIF
image_files.sort()

# define the output GIF file name
output_file = "point1_alter_io.gif"

# create a list to store the image file paths
image_paths = []

# iterate over the list of image file names and add the file path to image_paths
for filename in image_files:
    if filename.endswith(".jpg"):
        image_paths.append(os.path.join(directory, filename))

# create the GIF from the list of image file paths
with imageio.get_writer(output_file, mode="I") as writer:
    for image_path in image_paths:
        image = imageio.imread(image_path)
        writer.append_data(image)

# %%
import imageio
import os


# using a raw string
# directory = r"C:\Users\Lyle\Desktop\Computation and Modelling\image-processing\sine_plots\varying_freq"
directory = r"C:\Users\Lyle\Desktop\Computation and Modelling\image-processing\alter_io\point1_lut"


# create a list of image file names in the directory
image_files = os.listdir(directory)

# sort the list of image file names to ensure proper ordering in the GIF
image_files.sort()

# define the output GIF file name
output_file = "point1_lut_alter_io.gif"

# create a list to store the image file paths
image_paths = []

# iterate over the list of image file names and add the file path to image_paths
for filename in image_files:
    if filename.endswith(".jpg"):
        image_paths.append(os.path.join(directory, filename))

# create the GIF from the list of image file paths
with imageio.get_writer(output_file, mode="I") as writer:
    for image_path in image_paths:
        image = imageio.imread(image_path)
        writer.append_data(image)

# %% [markdown]
# ### Point2 Render

# %%
import imageio
import os


# using a raw string
# directory = r"C:\Users\Lyle\Desktop\Computation and Modelling\image-processing\sine_plots\varying_freq"
directory = r"C:\Users\Lyle\Desktop\Computation and Modelling\image-processing\alter_io\point2"


# create a list of image file names in the directory
image_files = os.listdir(directory)

# sort the list of image file names to ensure proper ordering in the GIF
image_files.sort()

# define the output GIF file name
output_file = "point2_alter_io.gif"

# create a list to store the image file paths
image_paths = []

# iterate over the list of image file names and add the file path to image_paths
for filename in image_files:
    if filename.endswith(".jpg"):
        image_paths.append(os.path.join(directory, filename))

# create the GIF from the list of image file paths
with imageio.get_writer(output_file, mode="I") as writer:
    for image_path in image_paths:
        image = imageio.imread(image_path)
        writer.append_data(image)

# %%
import imageio
import os


# using a raw string
# directory = r"C:\Users\Lyle\Desktop\Computation and Modelling\image-processing\sine_plots\varying_freq"
directory = r"C:\Users\Lyle\Desktop\Computation and Modelling\image-processing\alter_io\point2_lut"


# create a list of image file names in the directory
image_files = os.listdir(directory)

# sort the list of image file names to ensure proper ordering in the GIF
image_files.sort()

# define the output GIF file name
output_file = "point2_lut_alter_io.gif"

# create a list to store the image file paths
image_paths = []

# iterate over the list of image file names and add the file path to image_paths
for filename in image_files:
    if filename.endswith(".jpg"):
        image_paths.append(os.path.join(directory, filename))

# create the GIF from the list of image file paths
with imageio.get_writer(output_file, mode="I") as writer:
    for image_path in image_paths:
        image = imageio.imread(image_path)
        writer.append_data(image)

# %% [markdown]
# ### Point3 Render

# %%
import imageio
import os


# using a raw string
# directory = r"C:\Users\Lyle\Desktop\Computation and Modelling\image-processing\sine_plots\varying_freq"
directory = r"C:\Users\Lyle\Desktop\Computation and Modelling\image-processing\alter_io\point3"


# create a list of image file names in the directory
image_files = os.listdir(directory)

# sort the list of image file names to ensure proper ordering in the GIF
image_files.sort()

# define the output GIF file name
output_file = "point3_alter_io.gif"

# create a list to store the image file paths
image_paths = []

# iterate over the list of image file names and add the file path to image_paths
for filename in image_files:
    if filename.endswith(".jpg"):
        image_paths.append(os.path.join(directory, filename))

# create the GIF from the list of image file paths
with imageio.get_writer(output_file, mode="I") as writer:
    for image_path in image_paths:
        image = imageio.imread(image_path)
        writer.append_data(image)

# %%
import imageio
import os


# using a raw string
# directory = r"C:\Users\Lyle\Desktop\Computation and Modelling\image-processing\sine_plots\varying_freq"
directory = r"C:\Users\Lyle\Desktop\Computation and Modelling\image-processing\alter_io\point3_lut"


# create a list of image file names in the directory
image_files = os.listdir(directory)

# sort the list of image file names to ensure proper ordering in the GIF
image_files.sort()

# define the output GIF file name
output_file = "point3_lut_alter_io.gif"

# create a list to store the image file paths
image_paths = []

# iterate over the list of image file names and add the file path to image_paths
for filename in image_files:
    if filename.endswith(".jpg"):
        image_paths.append(os.path.join(directory, filename))

# create the GIF from the list of image file paths
with imageio.get_writer(output_file, mode="I") as writer:
    for image_path in image_paths:
        image = imageio.imread(image_path)
        writer.append_data(image)
